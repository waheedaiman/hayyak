# %%
import requests

API_KEY = "your_groq_api_key_here"  # replace with your key before running

response = requests.post(
    "https://api.groq.com/openai/v1/chat/completions",
    headers={
        "Authorization": f"Bearer {API_KEY}",
        "Content-Type": "application/json"
    },
    json={
        "model": "llama-3.1-8b-instant", # Updated model name to a known working model
        "messages": [
            {"role": "user", "content": "I am moving to Dubai with a budget of 6000 AED. What area should I consider?"}
        ]
    }
)

# Check if the request was successful
if response.status_code == 200:
    print(response.json()["choices"][0]["message"]["content"])
else:
    print(f"API request failed with status code: {response.status_code}")
    print(f"Response content: {response.text}")
    try:
        print(f"Response JSON: {response.json()}")
    except ValueError:
        print("Response is not valid JSON.")
# Out:
# Dubai has various neighborhoods to choose from, each with its own unique character and price range. Considering your budget of 6000 AED, here are some areas to consider:
#
# 1. **International City**: This area features affordable apartments, villas, and townhouses in a community with a mix of nationalities. You can find studios and one-bedroom apartments for around 30-40 AED per sq. ft.
# 2. **Dubai Silicon Oasis**: As one of the most affordable areas in Dubai, this community offers modern apartments with amenities like a gym, pool, and parking. Prices start from 35-50 AED per sq. ft.
# 3. **Dubai Sports City**: This area is a great option for sports enthusiasts, with easy access to Dubai Sports City and international cricket stadium. Prices range from 30-45 AED per sq. ft.
# 4. **Al Warqa**: A popular area for expats, Al Warqa offers affordable apartments, townhouses, and villas, with prices starting from 35-50 AED per sq. ft.
# ...
